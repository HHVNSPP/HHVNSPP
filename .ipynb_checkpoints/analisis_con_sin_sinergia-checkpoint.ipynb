# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np

#import warnings
import glob

# %%
#warnings.filterwarnings('ignore')
plt.style.use('seaborn')
sns.set()

# %%
data_s = pd.read_csv('sol_m_sin_4obj_64_1.txt.csv', sep=';', header=None)
data_ns = pd.read_csv('sol_m_sin_4obj_64_1 - copia.txt.csv', sep=';', header=None)

# %%
data_s.columns = ['col_{}'.format(idx) for idx in range(1, len(data_s.columns) + 1)]
data_ns.columns = ['col_{}'.format(idx) for idx in range(1, len(data_ns.columns) + 1)]

# %%
data_s.head()
# Out:
#                         col_1  col_2  col_3  col_4  col_5  col_6  col_7  \
# 0  2020-05-21 12:01:34.447768    721  63630  64000  138.0      0      0
# 1  2020-05-21 12:01:34.447768    721  63876  64000  137.0      0      0
# 2  2020-05-21 12:01:34.447768    721  63732  64000  136.0      0      0
# 3  2020-05-21 12:01:34.447768    721  63642  64000  136.0      0      0
# 4  2020-05-21 12:01:34.447768    721  63463  64000  135.0      0      0
#
#    col_8   col_9  col_10  ...      col_131 col_132      col_133 col_134  \
# 0    0.0  2225.0   173.0  ...  2999.461742   False  1347.525789   False
# 1    0.0  2646.0   141.0  ...  3152.640375   False  1400.716565    True
# 2    0.0  1863.0  1859.0  ...  3216.645271    True  1358.466004   False
# 3    0.0  1620.0  2094.0  ...  2319.809486    True  1946.833582   False
# 4    0.0  2125.0   197.0  ...  2299.806839    True  1559.628671   False
#
#        col_135 col_136      col_137 col_138      col_139 col_140
# 0  1742.208109   False  2696.291478    True  1341.333786
# 1  1824.104840   False  3064.660509   False  1100.608088
# 2  1725.850453   False  3069.127628    True  1355.653921
# 3  1807.611454   False  3161.735220    True  1350.675196
# 4  1878.963263    True  2980.686371   False  1243.313930
#
# [5 rows x 140 columns]

# %%
data_s.shape
data_ns.shape
# Out:
# (6875, 140)

# %%
data_s.set_index('col_1', inplace=True)
data_ns.set_index('col_1', inplace=True)

# %%
data_s.head()
# Out:
#                             col_2  col_3  col_4  col_5  col_6  col_7  col_8  \
# col_1
# 2020-05-21 12:01:34.447768    721  63630  64000  138.0      0      0    0.0
# 2020-05-21 12:01:34.447768    721  63876  64000  137.0      0      0    0.0
# 2020-05-21 12:01:34.447768    721  63732  64000  136.0      0      0    0.0
# 2020-05-21 12:01:34.447768    721  63642  64000  136.0      0      0    0.0
# 2020-05-21 12:01:34.447768    721  63463  64000  135.0      0      0    0.0
#
#                              col_9  col_10  col_11  ...      col_131  col_132  \
# col_1                                               ...
# 2020-05-21 12:01:34.447768  2225.0   173.0  2795.0  ...  2999.461742    False
# 2020-05-21 12:01:34.447768  2646.0   141.0  2756.0  ...  3152.640375    False
# 2020-05-21 12:01:34.447768  1863.0  1859.0  1193.0  ...  3216.645271     True
# 2020-05-21 12:01:34.447768  1620.0  2094.0  1106.0  ...  2319.809486     True
# 2020-05-21 12:01:34.447768  2125.0   197.0  2677.0  ...  2299.806839     True
#
#                                 col_133  col_134      col_135  col_136  \
# col_1
# 2020-05-21 12:01:34.447768  1347.525789    False  1742.208109    False
# 2020-05-21 12:01:34.447768  1400.716565     True  1824.104840    False
# 2020-05-21 12:01:34.447768  1358.466004    False  1725.850453    False
# 2020-05-21 12:01:34.447768  1946.833582    False  1807.611454    False
# 2020-05-21 12:01:34.447768  1559.628671    False  1878.963263     True
#
#                                 col_137  col_138      col_139  col_140
# col_1
# 2020-05-21 12:01:34.447768  2696.291478     True  1341.333786
# 2020-05-21 12:01:34.447768  3064.660509    False  1100.608088
# 2020-05-21 12:01:34.447768  3069.127628     True  1355.653921
# 2020-05-21 12:01:34.447768  3161.735220     True  1350.675196
# 2020-05-21 12:01:34.447768  2980.686371    False  1243.313930
#
# [5 rows x 139 columns]

# %%
data_s = data_s.loc['2020-05-05':]
data_ns = data_ns.loc['2020-05-05':]

# %%
data_s.head()
# Out:
#                             col_2  col_3  col_4  col_5  col_6  col_7  col_8  \
# col_1
# 2020-05-21 12:01:34.447768    721  63630  64000  138.0      0      0    0.0
# 2020-05-21 12:01:34.447768    721  63876  64000  137.0      0      0    0.0
# 2020-05-21 12:01:34.447768    721  63732  64000  136.0      0      0    0.0
# 2020-05-21 12:01:34.447768    721  63642  64000  136.0      0      0    0.0
# 2020-05-21 12:01:34.447768    721  63463  64000  135.0      0      0    0.0
#
#                              col_9  col_10  col_11  ...      col_131  col_132  \
# col_1                                               ...
# 2020-05-21 12:01:34.447768  2225.0   173.0  2795.0  ...  2999.461742    False
# 2020-05-21 12:01:34.447768  2646.0   141.0  2756.0  ...  3152.640375    False
# 2020-05-21 12:01:34.447768  1863.0  1859.0  1193.0  ...  3216.645271     True
# 2020-05-21 12:01:34.447768  1620.0  2094.0  1106.0  ...  2319.809486     True
# 2020-05-21 12:01:34.447768  2125.0   197.0  2677.0  ...  2299.806839     True
#
#                                 col_133  col_134      col_135  col_136  \
# col_1
# 2020-05-21 12:01:34.447768  1347.525789    False  1742.208109    False
# 2020-05-21 12:01:34.447768  1400.716565     True  1824.104840    False
# 2020-05-21 12:01:34.447768  1358.466004    False  1725.850453    False
# 2020-05-21 12:01:34.447768  1946.833582    False  1807.611454    False
# 2020-05-21 12:01:34.447768  1559.628671    False  1878.963263     True
#
#                                 col_137  col_138      col_139  col_140
# col_1
# 2020-05-21 12:01:34.447768  2696.291478     True  1341.333786
# 2020-05-21 12:01:34.447768  3064.660509    False  1100.608088
# 2020-05-21 12:01:34.447768  3069.127628     True  1355.653921
# 2020-05-21 12:01:34.447768  3161.735220     True  1350.675196
# 2020-05-21 12:01:34.447768  2980.686371    False  1243.313930
#
# [5 rows x 139 columns]

# %%
summary_s = data_s.groupby('col_1')[['col_2', 'col_8', 'col_9', 'col_10', 'col_11']].max()
summary_ns = data_s.groupby('col_1')[['col_2', 'col_8', 'col_9', 'col_10', 'col_11']].max()

# %%
summary_s.head()
# Out:
#                             col_2   col_8   col_9  col_10  col_11
# col_1
# 2020-05-21 12:01:34.447768    721  3360.0  3136.0  2995.0  2957.0
# 2020-05-21 12:13:35.249280    720  3591.0  3040.0  3332.0  3416.0
# 2020-05-21 12:25:35.796405   1141  3038.0  2966.0  2721.0  3244.0
# 2020-05-21 12:44:36.861030   1141  3327.0  3617.0  3024.0  4258.0
# 2020-05-21 13:03:37.812928   2221  3429.0  2832.0  2940.0  3159.0

# %%
prop_s = data_s.groupby('col_1')['col_2'].agg(['mean', 'count']).groupby('mean').mean().reset_index().sort_values('count', ascending=False)
prop_ns = data_ns.groupby('col_1')['col_2'].agg(['mean', 'count']).groupby('mean').mean().reset_index().sort_values('count', ascending=False)

# %%
prop_s.columns = ['time_elapsed', 'average_sol']
prop_ns.columns = ['time_elapsed', 'average_sol']
prop_s.to_csv("m128s.csv",index=None,header=None)
prop_ns.to_csv("m128ns.csv",index=None,header=None)

# %%
fig, ax = plt.subplots(figsize=(16, 8))
g = sns.lineplot(x='time_elapsed', y='average_sol', data=prop_s, markers=True)
_ = sns.scatterplot(x='time_elapsed', y='average_sol', data=prop_s, color='blue', markers='+')
h = sns.lineplot(x='time_elapsed', y='average_sol', data=prop_ns, markers=True)
plt.xscale('log')
a = sns.scatterplot(x='time_elapsed', y='average_sol', data=prop_ns, color='red', markers='+')
h.set_xlabel('Tiempo transcurrido en segundos')
a = g.set_ylabel('Promedio de soluciones no dominadas encontradas')

# %%
projects = pd.DataFrame()
for item in enumerate(range(12, data_s.shape[1], 2)):
    idx, col = item
    projects['prj_{}'.format(idx + 1)] = data_s['col_{}'.format(col)].apply(lambda x : True if x.strip() == 'True' else False)
    projects['prj_{}'.format(idx + 1)] = projects['prj_{}'.format(idx + 1)].astype('bool')

# %%
projects
# Out:
#                             prj_1  prj_2  prj_3  prj_4  prj_5  prj_6  prj_7  \
# col_1
# 2020-05-21 12:01:34.447768   True   True   True   True   True  False  False
# 2020-05-21 12:01:34.447768  False   True   True   True   True  False  False
# 2020-05-21 12:01:34.447768   True  False  False  False  False   True  False
# 2020-05-21 12:01:34.447768  False  False  False  False  False   True  False
# 2020-05-21 12:01:34.447768  False  False  False   True  False   True  False
# ...                           ...    ...    ...    ...    ...    ...    ...
# 2020-05-24 02:51:36.648966  False   True  False  False  False   True   True
# 2020-05-24 02:51:36.648966  False   True  False  False  False   True  False
# 2020-05-24 02:51:36.648966  False   True   True  False   True   True  False
# 2020-05-24 02:51:36.648966  False   True  False  False  False   True  False
# 2020-05-24 02:51:36.648966  False   True  False  False  False   True  False
#
#                             prj_8  prj_9  prj_10  ...  prj_55  prj_56  prj_57  \
# col_1                                             ...
# 2020-05-21 12:01:34.447768  False   True   False  ...   False    True   False
# 2020-05-21 12:01:34.447768  False  False   False  ...    True   False    True
# 2020-05-21 12:01:34.447768   True  False    True  ...    True    True    True
# 2020-05-21 12:01:34.447768   True  False    True  ...   False    True    True
# 2020-05-21 12:01:34.447768  False   True   False  ...   False   False    True
# ...                           ...    ...     ...  ...     ...     ...     ...
# 2020-05-24 02:51:36.648966   True  False    True  ...    True   False   False
# 2020-05-24 02:51:36.648966   True  False   False  ...   False    True   False
# 2020-05-24 02:51:36.648966  False  False   False  ...   False    True    True
# 2020-05-24 02:51:36.648966   True  False   False  ...   False    True   False
# 2020-05-24 02:51:36.648966   True  False   False  ...   False    True   False
#
#                             prj_58  prj_59  prj_60  prj_61  prj_62  prj_63  \
# col_1
# 2020-05-21 12:01:34.447768   False   False   False   False   False   False
# 2020-05-21 12:01:34.447768   False   False   False   False    True   False
# 2020-05-21 12:01:34.447768    True    True   False    True   False   False
# 2020-05-21 12:01:34.447768    True    True    True    True   False   False
# 2020-05-21 12:01:34.447768   False   False   False    True   False    True
# ...                            ...     ...     ...     ...     ...     ...
# 2020-05-24 02:51:36.648966   False    True    True    True   False    True
# 2020-05-24 02:51:36.648966    True   False    True    True   False   False
# 2020-05-24 02:51:36.648966    True   False   False    True   False   False
# 2020-05-24 02:51:36.648966    True   False    True    True   False   False
# 2020-05-24 02:51:36.648966    True   False    True    True   False   False
#
#                             prj_64
# col_1
# 2020-05-21 12:01:34.447768    True
# 2020-05-21 12:01:34.447768   False
# 2020-05-21 12:01:34.447768    True
# 2020-05-21 12:01:34.447768    True
# 2020-05-21 12:01:34.447768   False
# ...                            ...
# 2020-05-24 02:51:36.648966   False
# 2020-05-24 02:51:36.648966    True
# 2020-05-24 02:51:36.648966    True
# 2020-05-24 02:51:36.648966   False
# 2020-05-24 02:51:36.648966    True
#
# [14286 rows x 64 columns]

# %%
projects.reset_index(inplace=True)
order_s = projects.groupby('col_1').sum().sum().sort_values(ascending=False).reset_index()
#order.drop(0, axis='rows', inplace=True)

# %%
order_s.columns = ['project', 'count']

# %%
order_s.head()
# Out:
#   project    count
# 0  prj_37  10701.0
# 1  prj_31   9531.0
# 2  prj_38   9467.0
# 3  prj_57   9358.0
# 4  prj_21   9280.0

# %%
fig, ax = plt.subplots(figsize=(16, 8))
g = sns.barplot(y='project', x='count', data_s=order_s[:15], orient='h', ci='std')
g.set_xlabel('Occurrence in portfolios')
_ = g.set_ylabel('Best $15^{th}$ projects')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-5129c3a60cbb> in <module>
#       1 fig, ax = plt.subplots(figsize=(16, 8))
# ----> 2 g = sns.barplot(y='project', x='count', data_s=order_s[:15], orient='h', ci='std')
#       3 g.set_xlabel('Occurrence in portfolios')
#       4 _ = g.set_ylabel('Best $15^{th}$ projects')
#
# ~\anaconda4\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3148                           estimator, ci, n_boot, units, seed,
#    3149                           orient, color, palette, saturation,
# -> 3150                           errcolor, errwidth, capsize, dodge)
#    3151
#    3152     if ax is None:
#
# ~\anaconda4\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1613         """Initialize the plotter."""
#    1614         self.establish_variables(x, y, hue, data, orient,
# -> 1615                                  order, hue_order, units)
#    1616         self.establish_colors(color, palette, saturation)
#    1617         self.estimate_statistic(estimator, ci, n_boot, seed)
#
# ~\anaconda4\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     150                 if isinstance(var, str):
#     151                     err = "Could not interpret input '{}'".format(var)
# --> 152                     raise ValueError(err)
#     153
#     154             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'count'

# %%
fig, ax = plt.subplots(figsize=(16, 8))
g = sns.barplot(y='project', x='count', data=order[-15:], orient='h', ci='std')
g.set_xlabel('Occurrence in portfolios')
_ = g.set_ylabel('Worst $15^{th}$ projects')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-45002a21a90b> in <module>
#       1 fig, ax = plt.subplots(figsize=(16, 8))
# ----> 2 g = sns.barplot(y='project', x='count', data=order[-15:], orient='h', ci='std')
#       3 g.set_xlabel('Occurrence in portfolios')
#       4 _ = g.set_ylabel('Worst $15^{th}$ projects')
#
# NameError: name 'order' is not defined
